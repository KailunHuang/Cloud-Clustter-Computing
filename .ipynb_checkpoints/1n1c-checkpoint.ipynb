# %%
import json
import io
import time
from pprint import pprint
post_list = {}
with open('tinyTwitter.json','r', encoding="utf-8") as data_file:    
    data = json.load(data_file)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-a2b6788912e3> in <module>
#       6 with open('tinyTwitter.json','r', encoding="utf-8") as data_file:
#       7     data = json.load(data_file)
# ----> 8 data[:10]
#
# TypeError: unhashable type: 'slice'

# %%
import numpy
json1_file = open('tinyTwitter.json',encoding="utf-8")
json1_str = json1_file.read()
json1_data = json.loads(json1_str)
datapoints = numpy.array(json1_data['rows'])

# %%
import pandas as pd
dataset = pd.DataFrame.from_dict(json1_data['rows'])
dataset
# Out:
#                       id                   key  value  \
# 0    1212161512334336000  [sydney, 2020, 1, 1]      1
# 1    1212161512770437121  [sydney, 2020, 1, 1]      1
# 2    1212161513361793024  [sydney, 2020, 1, 1]      1
# 3    1212161513580105733  [sydney, 2020, 1, 1]      1
# 4    1212161514112770048  [sydney, 2020, 1, 1]      1
# ..                   ...                   ...    ...
# 994  1212167190352449536  [sydney, 2020, 1, 1]      1
# 995  1212167192311037952  [sydney, 2020, 1, 1]      1
# 996  1212167194848550912  [sydney, 2020, 1, 1]      1
# 997  1212167196429783040  [sydney, 2020, 1, 1]      1
# 998  1212167199793614848  [sydney, 2020, 1, 1]      1
#
#                                                    doc
# 0    {'_id': '1212161512334336000', '_rev': '1-a51c...
# 1    {'_id': '1212161512770437121', '_rev': '1-1f22...
# 2    {'_id': '1212161513361793024', '_rev': '1-3705...
# 3    {'_id': '1212161513580105733', '_rev': '1-85d9...
# 4    {'_id': '1212161514112770048', '_rev': '1-a301...
# ..                                                 ...
# 994  {'_id': '1212167190352449536', '_rev': '1-d05a...
# 995  {'_id': '1212167192311037952', '_rev': '1-50ec...
# 996  {'_id': '1212167194848550912', '_rev': '1-d501...
# 997  {'_id': '1212167196429783040', '_rev': '1-c2fe...
# 998  {'_id': '1212167199793614848', '_rev': '1-144b...
#
# [999 rows x 4 columns]

# %%
subdata = data["rows"]
doc_content = []
for post in subdata:
    doc_content.append(post["doc"]['entities'])
subdataset = pd.DataFrame(doc_content)
subdataset.columns
# Out:
# Index(['hashtags', 'symbols', 'user_mentions', 'urls', 'media'], dtype='object')

# %%
language = []
for post in subdata:
    language.append(post["doc"]["lang"])
language
# Out:
# ['es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'in',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'cy',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'et',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'und',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'pt',
#  'en',
#  'tr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'nl',
#  'tl',
#  'en',
#  'en',
#  'pt',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'ja',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'tl',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'fa',
#  'ht',
#  'en',
#  'und',
#  'en',
#  'und',
#  'en',
#  'th',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'tl',
#  'ar',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'ja',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'fr',
#  'und',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'zh',
#  'en',
#  'en',
#  'en',
#  'und',
#  'fr',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'tl',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'und',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'tl',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'zh',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'und',
#  'th',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'en',
#  'th',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'und',
#  'ro',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'th',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'ar',
#  'en',
#  'en',
#  'en',
#  'es',
#  'und',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'ja',
#  'en',
#  'pt',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'zh',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'de',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'fr',
#  'en',
#  'de',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'th',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'fa',
#  'en',
#  'en',
#  'de',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'zh',
#  'en',
#  'und',
#  'en',
#  'en',
#  'fr',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'ht',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'pl',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'th',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'et',
#  'en',
#  'en',
#  'en',
#  'en',
#  'ko',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'in',
#  'en',
#  'en',
#  'en',
#  'th',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'und',
#  'en',
#  'en',
#  'de',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'ar',
#  'en',
#  'en',
#  'ar',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'hu',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'ru',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'tl',
#  'en',
#  'und',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'und',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'th',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'ko',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'th',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en']
